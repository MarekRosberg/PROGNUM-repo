# %% [markdown]
# Name: Marek Rosberg
# Username: mrosberg
# Student s-number: S6200060
# Group: AS1

# %% [markdown]
# x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %% [markdown]
# ![dolphin.png](attachment:dolphin.png)

# %%
x = 1
x *=6
x *=5
x *=4
x *=3
x *=2
x *=1
print (x)
# Out:
# 720

# %%
from scipy.constants import G
m_1 = 5.9722e24
m_2 = 7.342e22
r = 385000000
F = G * m_1 * m_2 / r**2
print (F)
# Out:
# 1.974390205736684e+20

# %%
from scipy.constants import G, pi
P = 86400
a = 1495978700

m = ((4*(pi)**2*a**3)/(P**2*G))

print (m)
# Out:
# 2.652789306048023e+29

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143
