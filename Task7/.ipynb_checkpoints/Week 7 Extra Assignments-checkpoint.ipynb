# %% [markdown]
# #### 7.1

# %%
import numpy as np

A = np.array([[1, 2, 3],
              [0, -4, 1],
              [0, 3, -1]])

detA = np.linalg.det(A)
print(detA)
# ------------------------------
b = np.array([2, 2, -1])
x = np.linalg.solve(A, b)
print(x)
# -------------------------------
print(A.T @ A)
# -----------------------------
eigvals, eigvecs = np.linalg.eig(A)
print(eigvals)
# Out:
# 1.0
# [10. -1. -2.]
# [[ 1  2  3]
#  [ 2 29 -1]
#  [ 3 -1 11]]
# [ 1.         -4.79128785 -0.20871215]

# %% [markdown]
# #### 7.3

# %%
E = np.array([
[-0.06698874, -0.87275577, -0.48353891],
[ 0.49272847, -0.45034696,  0.74458463],
[-0.86760081, -0.1883746 ,  0.46019978]
])

print(E.T @ E)         # should be identity
print(np.linalg.det(E)) # should be 1
# -----------------------------------
eigvals, eigvecs = np.linalg.eig(E)
print(eigvals)
# -------------------------------------
alpha = np.deg2rad(192.25)
delta = np.deg2rad(27.4)

v = np.array([
    np.cos(delta)*np.cos(alpha),
    np.cos(delta)*np.sin(alpha),
    np.sin(delta)
])

print(v)
print(np.linalg.norm(v))
# ----------------------------------------
v2 = E @ v
print(v2)
# Out:
# [[ 1.00000000e+00 -3.66649539e-09  5.95746769e-09]
#  [-3.66649539e-09  1.00000001e+00 -3.38802084e-10]
#  [ 5.95746769e-09 -3.38802084e-10  9.99999986e-01]]
# 0.9999999982754763
# [-0.52856796+0.84889099j -0.52856796-0.84889099j  0.99999999+0.j        ]
# [-0.86760081 -0.1883746   0.46019978]
# 1.0
# [ 3.42052506e-09 -4.54291366e-09  9.99999996e-01]

# %% [markdown]
# #### 7.5

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9])
y = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0])

n = len(x)

V = np.zeros((n, n))
for i in range(n):
    for j in range(n):
        V[i, j] = x[i]**j

coeffs = np.linalg.solve(V, y)
# -----------------------------------
def poly(x_val, coeffs):
    y_val = 0
    for i in range(len(coeffs)):
        y_val += coeffs[i] * x_val**i
    return y_val
# -------------------------------------
x_plot = np.linspace(min(x), max(x), 500)
y_plot = [poly(xi, coeffs) for xi in x_plot]

plt.scatter(x, y)
plt.plot(x_plot, y_plot)
plt.show()

# %% [markdown]
# #### 7.6

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

spline = interp1d(x, y, kind='cubic')

x_plot = np.linspace(min(x), max(x), 500)
y_spline = spline(x_plot)

plt.scatter(x, y)
plt.plot(x_plot, y_spline)
plt.show()
# -----------------------------------
class Interpolation:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
        # polynomial
        n = len(x)
        V = np.zeros((n, n))
        for i in range(n):
            for j in range(n):
                V[i, j] = x[i]**j
        self.coeffs = np.linalg.solve(V, y)
        
        # spline
        self.spline = interp1d(x, y, kind='cubic')
        
        # linear
        self.linear = interp1d(x, y, kind='linear')
    
    def evaluate(self, x_val, method='linear'):
        if method == 'linear':
            return self.linear(x_val)
        elif method == 'polynomial':
            y_val = 0
            for i in range(len(self.coeffs)):
                y_val += self.coeffs[i]*x_val**i
            return y_val
        elif method == 'spline':
            return self.spline(x_val)

interp = Interpolation(x, y)

print(interp.evaluate(5.5, 'linear'))
print(interp.evaluate(5.5, 'polynomial'))
print(interp.evaluate(5.5, 'spline'))
# Out:
# 1.5
# 1.5702983233305758
# 1.5491249272587813

# %% [markdown]
# #### 7.7

# %%
import numpy as np
I = np.array([[2.0, 4.1],
              [2.5, 3.8]])

x, y = 0.2, 0.7

I_interp = (1-x)*(1-y)*I[0,0] + x*(1-y)*I[1,0] + \
           (1-x)*y*I[0,1] + x*y*I[1,1]

print(I_interp)
# Out:
# 3.4579999999999993

# %% [markdown]
# #### 7.10

# %%
import numpy as np
from scipy.optimize import leastsq
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

data = np.array([
   18.49,2094.75,0.3,100,
   35.48,2320.87,2.2,120,
   35.48,1224.9,3.0,80,
   11.34,872.13,1.2,80,
   7.12,432.2,0.4,70,
   9.82,751,0.3,75,
   23.66,1410,2.3,70,
   44,2700,4.0,110,
   66.7,5292,5.3,120,
   52.4,2550,5.2,100,
   55,5253,6.1,150,
   25.6,2419,3.2,110,
   26.19,2158,2.8,110
])

data = data.reshape(-1,4)

d = data[:,0]
v = data[:,1]
sigma_v = data[:,3]

# -------------------
def model(p, d):
    H0, c = p
    return H0*d + c
# ----------------------------
def residuals(p, d, v, sigma):
    return (v - model(p, d)) / sigma

p0 = [70, 0]
params, _ = leastsq(residuals, p0, args=(d, v, sigma_v))

H0_ls, c_ls = params
# ------------------------------
def f(d, H0, c):
    return H0*d + c

params_cf, _ = curve_fit(f, d, v, sigma=sigma_v)

H0_cf, c_cf = params_cf

# ------------------------------------
plt.scatter(d, v, marker='x')

d_fit = np.linspace(min(d), max(d), 200)

plt.plot(d_fit, f(d_fit, H0_ls, c_ls),
         label=f"leastsq: v={H0_ls:.2f}d+{c_ls:.2f}")

plt.plot(d_fit, f(d_fit, H0_cf, c_cf),
         label=f"curve_fit: v={H0_cf:.2f}d+{c_cf:.2f}")

plt.xlabel("Distance (Mpc)")
plt.ylabel("Velocity (km/s)")
plt.legend()
plt.show()
